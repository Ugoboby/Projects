# %% [markdown]
# # <a href="https://www.python.org/"><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/390px-Python_logo_and_wordmark.svg.png" style="max-width: 200px; display: inline" alt="Python"/></a> UE M2 Master MAS-MSS Projet Données Massives

# %% [markdown]
# # DEFI IA INSA TOULOUSE

# %% [markdown]
# Importation des librairies et du jeu de données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras.preprocessing.image as kpi
import os
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_hdf('train.hdf5')
validation = pd.read_hdf('validation.hdf5')

# %%
train
# Out:
#          0         1         2         3         4         5         6      \
# 0     0.041259  0.041259  0.032573  0.023887  0.029315  0.041259  0.045602
# 1    -0.211722 -0.264924 -0.274696 -0.236694 -0.156349 -0.059716  0.005429
# 2     0.214105  0.154930  0.136640  0.013987 -0.038733 -0.015063 -0.111894
# 3    -0.154837 -0.127768 -0.217638 -0.284770 -0.299929 -0.270694 -0.077960
# 4    -1.022780 -0.916376 -0.676425 -0.461445 -0.330069 -0.122690  0.178064
# 5     0.802624  0.759588  0.554090  0.391629  0.183979  0.013987 -0.232395
# 6    -0.334578 -0.232797 -0.126685 -0.184072 -0.047642  0.138595  0.263114
# 7     0.042344  0.039087  0.038001  0.067317  0.053202 -0.024972 -0.023887
# 8     0.004304  0.019366 -0.087148 -0.044112  0.145247  0.094679 -0.114046
# 9     0.017324  0.023821  0.176492  0.108278 -0.092036  0.003248  0.180824
# 10   -0.454931 -0.008686  0.390871  0.553734  0.754599  1.084668  1.229073
# ...

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.1)
clf.fit(train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-998af6ac29a3> in <module>
#       1 from sklearn import linear_model
#       2 clf = linear_model.Lasso(alpha=0.1)
# ----> 3 clf.fit(train)
#
# TypeError: fit() missing 1 required positional argument: 'y'
